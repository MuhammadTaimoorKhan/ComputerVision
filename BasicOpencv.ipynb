# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"D:\ComputerVision\Dataset\covid\01.jpeg")

# %%
img.shape
# Out:
# (3480, 4248, 3)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (3480, 4248, 3)

# %%
img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
img.shape
# Out:
# (3480, 4248)

# %%
plt.imshow(img)

# %%
cv2.imwrite("2.jpg",img)
# Out:
# True

# %%
img = cv2.resize(img,(224,224))

# %%
img.shape
# Out:
# (224, 224)

# %%
img = img/255

# %%
img
# Out:
# array([[0.03529412, 0.02745098, 0.02352941, ..., 0.02745098, 0.03137255,
#         0.05098039],
#        [0.02745098, 0.03137255, 0.01568627, ..., 0.00784314, 0.02745098,
#         0.03529412],
#        [0.02745098, 0.01960784, 0.01176471, ..., 0.01960784, 0.02352941,
#         0.02745098],
#        ...,
#        [0.        , 0.01568627, 0.        , ..., 0.01960784, 0.01960784,
#         0.02745098],
#        [0.        , 0.00392157, 0.        , ..., 0.01960784, 0.01960784,
#         0.02352941],
#        [0.        , 0.        , 0.00392157, ..., 0.03137255, 0.03137255,
#         0.03137255]], shape=(224, 224))
